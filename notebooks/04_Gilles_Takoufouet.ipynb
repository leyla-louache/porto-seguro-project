# %%
import json
from pathlib import Path
RESULTS_DIR = Path("../results")
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Save results:

# %%
RESULTS_DIR = Path("../results")
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

NOTEBOOK_ID = "04"

all_results = [
    {
        "model": "MODEL NAME",        # e.g. "Logistic Regression", "LightGBM"
        "auc": 0.0000,                # roc_auc_score(y_test, proba)
        "gini": 0.0000,               # 2 * auc - 1
        "ap": None,                   # average_precision_score(y_test, proba), or None
        "base_rate": 0.0364,          # y_test.mean() — same split for everyone
        "params": {
            # The hyperparameters you actually used. Copy them from your model
            # definition, or use model.get_params() and paste the output.
            "param_name": "value",
        },
        "notes":  "With or without CALC ?", # e.g. "tuned, without calc" /
                                       # "default params, hold-out"
    },

    # --- Second model: copy the block above and edit ---
    {
        "model": "MODEL NAME",
        "auc": 0.0000,
        "gini": 0.0000,
        "ap": None,
        "base_rate": 0.0364,
        "params": {
            "param_name": "value",
        },
        "notes": "With or without CALC ?",
    },
]


path = RESULTS_DIR / f"{NOTEBOOK_ID}_models.json"
with open(path, "w") as f:
    json.dump(all_results, f, indent=2)

print(f"Results saved in {path}")
print(pd.DataFrame(all_results)[["model", "notes", "gini", "ap"]].to_string(index=False))
